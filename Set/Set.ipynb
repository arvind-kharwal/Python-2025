# %%
s = set()
print(s)
# Out:
# set()

# %%
s = set([1,2,3])
print(s)
type(s)
# Out:
# {1, 2, 3}
# set

# %%
s1 = {1,2,3}
s = s1.update([10,2,13],{4,67})
print(s1)
# Out:
# {1, 2, 3, 67, 4, 10, 13}

# %%
s = {1,2,3,4}
s.discard(4)
print(s)
# Out:
# {1, 2, 3}

# %%
s = {1,2,3,4}
s.discard(41)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
s = {1,2,3,4}
s.remove(41)
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 s = {1,2,3,4}
# ----> 2 s.remove(41)
#       3 print(s)
#
# KeyError: 41

# %%
s = {1,2,3,4} 
s.pop()
print(s)
# Out:
# {2, 3, 4}

# %%
s = 'Python Programming'
set1 = set(s)
print(set1)
# Out:
# {'g', ' ', 'n', 'm', 't', 'P', 'o', 'h', 'a', 'r', 'i', 'y'}

# %%
s = 'Python Programming'
set1 = set(s)
print(set1)
# Out:
# {'g', ' ', 'n', 'm', 't', 'P', 'o', 'h', 'a', 'r', 'i', 'y'}
