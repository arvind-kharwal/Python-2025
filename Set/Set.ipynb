# %%
s = set()
print(s)
# Out:
# set()

# %%
s = set([1,2,3])
print(s)
type(s)
# Out:
# {1, 2, 3}
# set

# %%
s1 = {1,2,3}
s = s1.update([10,2,13],{4,67})
print(s1)
# Out:
# {1, 2, 3, 67, 4, 10, 13}

# %%
s = {1,2,3,4}
s.discard(4)
print(s)
# Out:
# {1, 2, 3}

# %%
s = {1,2,3,4}
s.discard(41)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}
