# %%
with open('demo.txt','r') as f:
    data = f.read()
    print(data)
# Out:
# String
# ...
# 1. What is String?
# 2. Encoding & Decoding
# 3. How to  create string?
# 4. How to access string?
# 5. How to update the string?
# 6. Length
# 7. Concatenation of string
# 8. Repetition of string
# 9. Iterating through string
# 10. Membership

# %%
with open('demo.txt','r') as f:
    data = f.readline()
    print(data)
# Out:
# String

# %%
with open('demo.txt','r') as f:
    data = f.readline(3)
    print(data)
# Out:
# Str

# %%
with open('demo.txt','r') as f:
    data = f.readlines()
    print(data)
# Out:
# ['String\n', '=============\n', '1. What is String?\n', '2. Encoding & Decoding\n', '3. How to  create string?\n', '4. How to access string?\n', '5. How to update the string?\n', '6. Length \n', '7. Concatenation of string\n', '8. Repetition of string\n', '9. Iterating through string\n', '10. Membership']

# %%
with open('demos.txt','w') as f:
    data = f.write('Hello This is demos.txt')
    print(data)
# Out:
# 23

# %%
with open('demos.txt','w') as f:
    f.write('Hello This is demos.txt')
    print(f)
# Out:
# <_io.TextIOWrapper name='demos.txt' mode='w' encoding='cp1252'>

# %%
with open('demos.txt','w') as f:
    f.write('Hello This is demos.txt')
    data = f.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[7], line 3
#       1 with open('demos.txt','w') as f:
#       2     f.write('Hello This is demos.txt')
# ----> 3     data = f.read()
#       4     print(data)
#
# UnsupportedOperation: not readable

# %%
with open('demos.txt','w+') as f:
    f.write('Hello, File')
    data = f.read()
    print(data)

# %%
with open('demos.txt','w+') as f:
    f.write('Hello, File')
    f.seek(0)
    data = f.read()
    print(data)
# Out:
# Hello, File

# %%
with open('demos.txt','r+') as f:
    data = f.read()
    print(data)
# Out:
# Hello, File

# %%
with open('rplus.txt','r+') as f:
    data = f.read()
    print(data)
    f.write('Using r+ mode')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 with open('rplus.txt','r+') as f:
#       2     data = f.read()
#       3     print(data)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rplus.txt'

# %%
with open('demos.txt','r+') as f:
    data = f.read()
    print(data)
    f.write('Using r+ mode')
# Out:
# Hello, File

# %%
with open('demos.txt','a+') as f:
    data = f.read()
    print(data)
    f.seek(0)
    f.write('Using r+ mode')
