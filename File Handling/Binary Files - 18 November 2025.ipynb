# %%
import pickle

# %%
with open('demo.dat','wb') as f:
    l1 = [1,'File Handling in Python',4.56]
    pickle.dump(l1,f)

# %%
with open('demo.dat','rb') as f:
    l1 = [1,'File Handling in Python',4.56]
    pickle.dump(l1,f)
