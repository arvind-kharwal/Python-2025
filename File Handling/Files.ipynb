# %%
with open('demo.txt','r') as f:
    line1 = f.readline()
    print(line1)
# Out:
# String

# %%
with open('demo.txt','r') as f:
    line1 = f.readline()
    line2 = f.readline()
    print(line1,line2)
# Out:
# String
# ...

# %%
with open('demo.txt','r') as f:
    while True:
            line = f.readline()
