# %%
d = {1:'a',2:'v'}
print(d)
# Out:
# {1: 'a', 2: 'v'}

# %%
d.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d.pop(1)
# Out:
# 'a'

# %%
d
# Out:
# {2: 'v'}

# %%
d = {1:'a',2:'v'}
print(d)
d.popitem()
# Out:
# {1: 'a', 2: 'v'}
# (2, 'v')

# %%
d
# Out:
# {1: 'a'}
