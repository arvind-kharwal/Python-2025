# %%
s = input('Enter the string')
l = s.split()
print(l)
d = {}
for i in l:
    if i not in d:
        d[i] = 0
    d[i]=d[i]+1
print(d)
# Out:
# Enter the string hello hello hello hi
# ['hello', 'hello', 'hello', 'hi']
# {'hello': 3, 'hi': 1}
