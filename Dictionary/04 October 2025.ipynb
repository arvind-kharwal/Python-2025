# %%
s = input('Enter the string')
l = s.split()
print(l)
d = {}
for i in l:
    if i not in d:
        d[i] = 0
    d[i]=d[i]+1
print(d)
# Out:
# Enter the string a is a and a is a
# ['a', 'is', 'a', 'and', 'a', 'is', 'a']
# {'a': 4, 'is': 2, 'and': 1}

# %%
d = {'a':2,'b':10}
d1 =
